# %% [markdown]
# # 가상화폐 시세 판단하기

# %% [markdown]
# > 최고가와 최저가의 차이를 변동폭으로 정의할 때 (시가 + 변동폭)이 최고가 보다 높을 경우 "상승장", 그렇지 않은 경우 "하락장" 문자열을 출력하라.
#
# |Key Name        |     Description|
# |---|---|
# |opeing_price    |최근 24시간 내 시작 거래금액|
# |closing_price   |최근 24시간 내 마지막 거래금액|
# |min_price       |최근 24시간 내 최저 거래금액|
# |max_price       |최근 24시간 내 최고 거래금액|

# %%
import requests
from pprint import pprint
btc = requests.get('https://api.bithumb.com/public/ticker/btc').json()['data']
pprint(btc)
# Out:
# {'24H_fluctate': '-45000',
#  '24H_fluctate_rate': '-1.04',
#  'average_price': '4300948.365',
#  'buy_price': '4275000',
#  'closing_price': '4275000',
#  'date': '1546568822133',
#  'max_price': '4339000',
#  'min_price': '4250000',
#  'opening_price': '4320000',
#  'sell_price': '4277000',
#  'units_traded': '18055.70426827',
#  'volume_1day': '18055.70426827',
#  'volume_7day': '56224.25563717'}

# %%
#강사님 풀이

bdp = float(btc['max_price']) - float(btc['min_price'])
if int(btc['opening_price']) + bdp > int(btc['max_price']):
    print("상승장")
else:
    print("하락장")
# Out:
# 상승장

# %%
# 아래에 코드를 작성하세요.
#내 풀이

max = int(btc['max_price'])
min = int(btc['min_price'])
open = int(btc['opening_price'])

change = max - min
if open + change > max:
    print("상승장")
else:
    print("하락장")
# Out:
# 상승장

# %% [markdown]
# ## 모든 가상화폐 시세 판단하기
#
#
# > currrency dictionary에 담겨있는 모든 가상화폐 거래내역을 바탕으로 출력하라.
# >
# > 예외 처리에 유의하세요.
#
#
#
# ```
# 예시 출력)
# BTC 상승장
# ETH 상승장
# DASH 상승장
# LTC 하락장
# ETC 하락장
# XRP 상승장
# BCH 상승장
# ...
# ```

# %%
currency = requests.get('https://api.bithumb.com/public/ticker/all').json()['data']
pprint(currency)
# Out:
# {'ABT': {'24H_fluctate': '-9.6',
#          '24H_fluctate_rate': '-9.14',
#          'average_price': '103.2335',
#          'buy_price': '95.4',
#          'closing_price': '95.4',
#          'max_price': '115',
#          'min_price': '94.1',
#          'opening_price': '105',
#          'sell_price': '95.8',
#          'units_traded': '11351567.08401732',
#          'volume_1day': '11351567.08401732',
#          'volume_7day': '50702305.595995697921657788'},
#  'ADA': {'24H_fluctate': '-2.1',
#          '24H_fluctate_rate': '-2.70',
#          'average_price': '77.1692',
#          'buy_price': '75.5',
#          'closing_price': '75.5',
#          'max_price': '79.3',
#          'min_price': '75.1',
#          'opening_price': '77.6',
#          'sell_price': '76.3',
#          'units_traded': '2077550.54266183',
#          'volume_1day': '2077550.54266183',
#          'volume_7day': '39717998.22495277'},
#  'ADD': [],
#  'AE': {'24H_fluctate': '-31',
#         '24H_fluctate_rate': '-1.88',
#         'average_price': '1632.25',
#         'buy_price': '1602',
#         'closing_price': '1610',
#         'max_price': '1678',
#         'min_price': '1600',
#         'opening_price': '1641',
#         'sell_price': '1610',
#         'units_traded': '66015.42505548',
#         'volume_1day': '66015.42505548',
#         'volume_7day': '1896737.232137726162182133'},
#  'AMO': {'24H_fluctate': '-0.17',
#          '24H_fluctate_rate': '-9.65',
#          'average_price': '1.6939',
#          'buy_price': '1.57',
#          'closing_price': '1.59',
#          'max_price': '1.78',
#          'min_price': '1.56',
#          'opening_price': '1.76',
#          'sell_price': '1.59',
#          'units_traded': '700774067.26106068',
#          'volume_1day': '700774067.26106068',
#          'volume_7day': '24122574177.731595320725033356'},
#  'BAT': {'24H_fluctate': '-3',
#          '24H_fluctate_rate': '-2.01',
#          'average_price': '147.0524',
#          'buy_price': '146',
#          'closing_price': '146',
#          'max_price': '154',
#          'min_price': '144',
#          'opening_price': '149',
#          'sell_price': '147',
#          'units_traded': '1510750.25549052',
#          'volume_1day': '1510750.25549052',
#          'volume_7day': '7012918.299910630100902915'},
#  'BCD': {'24H_fluctate': '-32',
#          '24H_fluctate_rate': '-3.10',
#          'average_price': '1015.6396',
#          'buy_price': '996',
#          'closing_price': '1000',
#          'max_price': '1040',
#          'min_price': '997',
#          'opening_price': '1032',
#          'sell_price': '1000',
#          'units_traded': '120455.14215646',
#          'volume_1day': '120455.14215646',
#          'volume_7day': '1812092.37917988'},
#  'BCH': {'24H_fluctate': '-11100',
#          '24H_fluctate_rate': '-5.81',
#          'average_price': '183766.2836',
#          'buy_price': '179800',
#          'closing_price': '179700',
#          'max_price': '191500',
#          'min_price': '177300',
#          'opening_price': '190800',
#          'sell_price': '180000',
#          'units_traded': '46228.1690958',
#          'volume_1day': '46228.1690958',
#          'volume_7day': '552118.71643334'},
#  'BHPC': {'24H_fluctate': '-14',
#           '24H_fluctate_rate': '-1.54',
#           'average_price': '909.5801',
#           'buy_price': '894',
#           'closing_price': '894',
#           'max_price': '927',
#           'min_price': '890',
#           'opening_price': '908',
#           'sell_price': '898',
#           'units_traded': '488669.59905765',
#           'volume_1day': '488669.59905765',
#           'volume_7day': '8376693.538561527652769304'},
#  'BLACK': [],
#  'BSV': {'24H_fluctate': '-4300',
#          '24H_fluctate_rate': '-4.15',
#          'average_price': '100389.5178',
#          'buy_price': '99100',
#          'closing_price': '99200',
#          'max_price': '103800',
#          'min_price': '97400',
#          'opening_price': '103500',
#          'sell_price': '99450',
#          'units_traded': '23049.06572066',
#          'volume_1day': '23049.06572066',
#          'volume_7day': '269095.40006854'},
#  'BTC': {'24H_fluctate': '-48000',
#          '24H_fluctate_rate': '-1.11',
#          'average_price': '4300830.5616',
#          'buy_price': '4275000',
#          'closing_price': '4275000',
#          'max_price': '4339000',
#          'min_price': '4250000',
#          'opening_price': '4323000',
#          'sell_price': '4276000',
#          'units_traded': '18058.92396282',
#          'volume_1day': '18058.92396282',
#          'volume_7day': '56220.26110519'},
#  'BTG': {'24H_fluctate': '-360',
#          '24H_fluctate_rate': '-2.43',
#          'average_price': '14462.992',
#          'buy_price': '14440',
#          'closing_price': '14450',
#          'max_price': '14980',
#          'min_price': '12970',
#          'opening_price': '14810',
#          'sell_price': '14450',
#          'units_traded': '23269332.73053701',
#          'volume_1day': '23269332.73053701',
#          'volume_7day': '101529002.93584794'},
#  'BZNT': {'24H_fluctate': '-0.7',
#           '24H_fluctate_rate': '-2.47',
#           'average_price': '27.9285',
#           'buy_price': '27.6',
#           'closing_price': '27.6',
#           'max_price': '29.3',
#           'min_price': '27',
#           'opening_price': '28.3',
#           'sell_price': '28',
#           'units_traded': '35177141.30401007',
#           'volume_1day': '35177141.30401007',
#           'volume_7day': '192161410.050833452831885565'},
#  'CHL': [],
#  'CMT': {'24H_fluctate': '-0.6',
#          '24H_fluctate_rate': '-1.70',
#          'average_price': '34.5413',
#          'buy_price': '34',
#          'closing_price': '34.6',
#          'max_price': '36.2',
#          'min_price': '32.4',
#          'opening_price': '35.2',
#          'sell_price': '34.5',
#          'units_traded': '4581969.50945042',
#          'volume_1day': '4581969.50945042',
#          'volume_7day': '36136706.744095702860476475'},
#  'CTXC': {'24H_fluctate': '-4',
#           '24H_fluctate_rate': '-3.36',
#           'average_price': '117.996',
#           'buy_price': '115',
#           'closing_price': '115',
#           'max_price': '124',
#           'min_price': '113',
#           'opening_price': '119',
#           'sell_price': '117',
#           'units_traded': '1321900.62871294',
#           'volume_1day': '1321900.62871294',
#           'volume_7day': '11457053.712621014673753123'},
#  'DASH': {'24H_fluctate': '-2550',
#           '24H_fluctate_rate': '-2.73',
#           'average_price': '90598.5555',
#           'buy_price': '90300',
#           'closing_price': '90550',
#           'max_price': '93500',
#           'min_price': '88100',
#           'opening_price': '93100',
#           'sell_price': '90500',
#           'units_traded': '3614194.97123308',
#           'volume_1day': '3614194.97123308',
#           'volume_7day': '32289349.79652674'},
#  'ELF': {'24H_fluctate': '6',
#          '24H_fluctate_rate': '4.68',
#          'average_price': '132.2746',
#          'buy_price': '133',
#          'closing_price': '134',
#          'max_price': '139',
#          'min_price': '125',
#          'opening_price': '128',
#          'sell_price': '135',
#          'units_traded': '5164679.6121298',
#          'volume_1day': '5164679.6121298',
#          'volume_7day': '18480596.096766113183667368'},
#  'ENJ': {'24H_fluctate': '-1.7',
#          '24H_fluctate_rate': '-3.79',
#          'average_price': '44.0021',
#          'buy_price': '42.9',
#          'closing_price': '43.1',
#          'max_price': '45.7',
#          'min_price': '42.6',
#          'opening_price': '44.8',
#          'sell_price': '43.2',
#          'units_traded': '3429225.54419568',
#          'volume_1day': '3429225.54419568',
#          'volume_7day': '22942276.115158192816118614'},
#  'EOS': {'24H_fluctate': '-142',
#          '24H_fluctate_rate': '-4.53',
#          'average_price': '3045.2715',
#          'buy_price': '2990',
#          'closing_price': '2992',
#          'max_price': '3166',
#          'min_price': '2930',
#          'opening_price': '3134',
#          'sell_price': '2992',
#          'units_traded': '2397788.48436815',
#          'volume_1day': '2397788.48436815',
#          'volume_7day': '22689702.55504354'},
#  'EOSDAC': [],
#  'ETC': {'24H_fluctate': '-250',
#          '24H_fluctate_rate': '-4.20',
#          'average_price': '5775.3136',
#          'buy_price': '5680',
#          'closing_price': '5690',
#          'max_price': '5995',
#          'min_price': '5640',
#          'opening_price': '5940',
#          'sell_price': '5690',
#          'units_traded': '528535.16799124',
#          'volume_1day': '528535.16799124',
#          'volume_7day': '1869488.498614439873039507'},
#  'ETH': {'24H_fluctate': '-3900',
#          '24H_fluctate_rate': '-2.28',
#          'average_price': '168114.5597',
#          'buy_price': '166600',
#          'closing_price': '166900',
#          'max_price': '173800',
#          'min_price': '163500',
#          'opening_price': '170800',
#          'sell_price': '166900',
#          'units_traded': '580760.70045675',
#          'volume_1day': '580760.70045675',
#          'volume_7day': '1972343.183541297181064519'},
#  'ETHOS': {'24H_fluctate': '-14',
#            '24H_fluctate_rate': '-1.25',
#            'average_price': '1107.6905',
#            'buy_price': '1095',
#            'closing_price': '1099',
#            'max_price': '1177',
#            'min_price': '1050',
#            'opening_price': '1113',
#            'sell_price': '1099',
#            'units_traded': '255440.14607046',
#            'volume_1day': '255440.14607046',
#            'volume_7day': '6294893.96415914'},
#  'GNT': {'24H_fluctate': '-1.8',
#          '24H_fluctate_rate': '-2.32',
#          'average_price': '76.4727',
#          'buy_price': '75.6',
#          'closing_price': '75.6',
#          'max_price': '77.8',
#          'min_price': '75.3',
#          'opening_price': '77.4',
#          'sell_price': '76.2',
#          'units_traded': '1035043.07700724',
#          'volume_1day': '1035043.07700724',
#          'volume_7day': '37290483.872657287038279961'},
#  'GTO': {'24H_fluctate': '-1.1',
#          '24H_fluctate_rate': '-1.50',
#          'average_price': '74.0844',
#          'buy_price': '71.9',
#          'closing_price': '72',
#          'max_price': '78.1',
#          'min_price': '71.2',
#          'opening_price': '73.1',
#          'sell_price': '72.9',
#          'units_traded': '2273063.76542207',
#          'volume_1day': '2273063.76542207',
#          'volume_7day': '24880315.02315879'},
#  'HC': {'24H_fluctate': '-9',
#         '24H_fluctate_rate': '-0.62',
#         'average_price': '1444.4539',
#         'buy_price': '1413',
#         'closing_price': '1431',
#         'max_price': '1512',
#         'min_price': '1380',
#         'opening_price': '1440',
#         'sell_price': '1431',
#         'units_traded': '81255.03893315',
#         'volume_1day': '81255.03893315',
#         'volume_7day': '883179.86047459'},
#  'HORUS': [],
#  'ICX': {'24H_fluctate': '3',
#          '24H_fluctate_rate': '1.04',
#          'average_price': '294.8585',
#          'buy_price': '287',
#          'closing_price': '290',
#          'max_price': '318',
#          'min_price': '281',
#          'opening_price': '287',
#          'sell_price': '290',
#          'units_traded': '2160000.92376089',
#          'volume_1day': '2160000.92376089',
#          'volume_7day': '5059303.317827308297395376'},
#  'INS': {'24H_fluctate': '34',
#          '24H_fluctate_rate': '10.49',
#          'average_price': '339.8556',
#          'buy_price': '357',
#          'closing_price': '358',
#          'max_price': '366',
#          'min_price': '316',
#          'opening_price': '324',
#          'sell_price': '359',
#          'units_traded': '4285048.7335279',
#          'volume_1day': '4285048.7335279',
#          'volume_7day': '11861201.2047815091'},
#  'IOST': {'24H_fluctate': '-0.09',
#           '24H_fluctate_rate': '-1.39',
#           'average_price': '6.3297',
#           'buy_price': '6.3',
#           'closing_price': '6.38',
#           'max_price': '6.52',
#           'min_price': '6.16',
#           'opening_price': '6.47',
#           'sell_price': '6.38',
#           'units_traded': '423021944.23323556',
#           'volume_1day': '423021944.23323556',
#           'volume_7day': '1445081108.066234314024641302'},
#  'ITC': {'24H_fluctate': '-4',
#          '24H_fluctate_rate': '-2.85',
#          'average_price': '136.6778',
#          'buy_price': '135',
#          'closing_price': '136',
#          'max_price': '141',
#          'min_price': '133',
#          'opening_price': '140',
#          'sell_price': '136',
#          'units_traded': '1495581.01609136',
#          'volume_1day': '1495581.01609136',
#          'volume_7day': '17481201.537970639705758781'},
#  'KNC': {'24H_fluctate': '-7',
#          '24H_fluctate_rate': '-3.80',
#          'average_price': '179.4902',
#          'buy_price': '176',
#          'closing_price': '177',
#          'max_price': '185',
#          'min_price': '173',
#          'opening_price': '184',
#          'sell_price': '177',
#          'units_traded': '806506.64795387',
#          'volume_1day': '806506.64795387',
#          'volume_7day': '7202609.490490646089975132'},
#  'LINK': {'24H_fluctate': '58',
#           '24H_fluctate_rate': '15.93',
#           'average_price': '403.7634',
#           'buy_price': '420',
#           'closing_price': '422',
#           'max_price': '446',
#           'min_price': '362',
#           'opening_price': '364',
#           'sell_price': '424',
#           'units_traded': '12412759.90835239',
#           'volume_1day': '12412759.90835239',
#           'volume_7day': '16762606.856225832613136453'},
#  'LOOM': {'24H_fluctate': '-2.1',
#           '24H_fluctate_rate': '-3.72',
#           'average_price': '57.6832',
#           'buy_price': '54.3',
#           'closing_price': '54.3',
#           'max_price': '63.8',
#           'min_price': '53.1',
#           'opening_price': '56.4',
#           'sell_price': '54.9',
#           'units_traded': '23535332.09592164',
#           'volume_1day': '23535332.09592164',
#           'volume_7day': '46856049.851699057015732253'},
#  'LRC': {'24H_fluctate': '-29',
#          '24H_fluctate_rate': '-4.92',
#          'average_price': '576.4209',
#          'buy_price': '558',
#          'closing_price': '560',
#          'max_price': '595',
#          'min_price': '560',
#          'opening_price': '589',
#          'sell_price': '560',
#          'units_traded': '145059.87288059',
#          'volume_1day': '145059.87288059',
#          'volume_7day': '2933248.857871617643527395'},
#  'LTC': {'24H_fluctate': '-890',
#          '24H_fluctate_rate': '-2.43',
#          'average_price': '35922.0391',
#          'buy_price': '35600',
#          'closing_price': '35660',
#          'max_price': '36920',
#          'min_price': '34940',
#          'opening_price': '36550',
#          'sell_price': '35660',
#          'units_traded': '11835.74909976',
#          'volume_1day': '11835.74909976',
#          'volume_7day': '176031.53992017'},
#  'MCO': {'24H_fluctate': '-21',
#          '24H_fluctate_rate': '-0.80',
#          'average_price': '2583.6465',
#          'buy_price': '2590',
#          'closing_price': '2590',
#          'max_price': '2637',
#          'min_price': '2533',
#          'opening_price': '2611',
#          'sell_price': '2622',
#          'units_traded': '804300.09960361',
#          'volume_1day': '804300.09960361',
#          'volume_7day': '1918202.32887829'},
#  'MEETONE': [],
#  'MITH': {'24H_fluctate': '-2.4',
#           '24H_fluctate_rate': '-3.37',
#           'average_price': '69.8303',
#           'buy_price': '68.8',
#           'closing_price': '68.8',
#           'max_price': '71.4',
#           'min_price': '68.3',
#           'opening_price': '71.2',
#           'sell_price': '69',
#           'units_traded': '9113257.16930668',
#           'volume_1day': '9113257.16930668',
#           'volume_7day': '106485267.74120550599621313'},
#  'OCN': {'24H_fluctate': '-0.2',
#          '24H_fluctate_rate': '-5.03',
#          'average_price': '3.8433',
#          'buy_price': '3.77',
#          'closing_price': '3.77',
#          'max_price': '4.03',
#          'min_price': '3.67',
#          'opening_price': '3.97',
#          'sell_price': '3.8',
#          'units_traded': '55855249.03888849',
#          'volume_1day': '55855249.03888849',
#          'volume_7day': '1600216775.504713560050201454'},
#  'OMG': {'24H_fluctate': '-30',
#          '24H_fluctate_rate': '-1.78',
#          'average_price': '1645.0112',
#          'buy_price': '1640',
#          'closing_price': '1654',
#          'max_price': '1684',
#          'min_price': '1612',
#          'opening_price': '1684',
#          'sell_price': '1655',
#          'units_traded': '1241922.73944469',
#          'volume_1day': '1241922.73944469',
#          'volume_7day': '10924420.682021818906013623'},
#  'PAY': {'24H_fluctate': '-60',
#          '24H_fluctate_rate': '-3.33',
#          'average_price': '1786.8951',
#          'buy_price': '1740',
#          'closing_price': '1740',
#          'max_price': '1845',
#          'min_price': '1730',
#          'opening_price': '1800',
#          'sell_price': '1741',
#          'units_traded': '190424.50960496',
#          'volume_1day': '190424.50960496',
#          'volume_7day': '8350805.899904288266193479'},
#  'PIVX': {'24H_fluctate': '-34',
#           '24H_fluctate_rate': '-3.54',
#           'average_price': '939.1732',
#           'buy_price': '918',
#           'closing_price': '926',
#           'max_price': '972',
#           'min_price': '914',
#           'opening_price': '960',
#           'sell_price': '926',
#           'units_traded': '144452.36010544',
#           'volume_1day': '144452.36010544',
#           'volume_7day': '10439747.36184645'},
#  'PLY': {'24H_fluctate': '-1',
#          '24H_fluctate_rate': '-2.57',
#          'average_price': '38.1528',
#          'buy_price': '37.8',
#          'closing_price': '37.8',
#          'max_price': '40',
#          'min_price': '36.4',
#          'opening_price': '38.8',
#          'sell_price': '37.9',
#          'units_traded': '10152587.3454848',
#          'volume_1day': '10152587.3454848',
#          'volume_7day': '109027932.381338524'},
#  'POLY': {'24H_fluctate': '-7',
#           '24H_fluctate_rate': '-4.32',
#           'average_price': '157.3109',
#           'buy_price': '155',
#           'closing_price': '155',
#           'max_price': '162',
#           'min_price': '155',
#           'opening_price': '162',
#           'sell_price': '157',
#           'units_traded': '1154843.10119114',
#           'volume_1day': '1154843.10119114',
#           'volume_7day': '9947810.836797255355654461'},
#  'POWR': {'24H_fluctate': '-18',
#           '24H_fluctate_rate': '-3.32',
#           'average_price': '528.702',
#           'buy_price': '519',
#           'closing_price': '523',
#           'max_price': '545',
#           'min_price': '512',
#           'opening_price': '541',
#           'sell_price': '523',
#           'units_traded': '417070.23705944',
#           'volume_1day': '417070.23705944',
#           'volume_7day': '6101645.07206919'},
#  'PPT': {'24H_fluctate': '-29',
#          '24H_fluctate_rate': '-1.72',
#          'average_price': '1662.6088',
#          'buy_price': '1645',
#          'closing_price': '1650',
#          'max_price': '1691',
#          'min_price': '1621',
#          'opening_price': '1679',
#          'sell_price': '1669',
#          'units_traded': '37129.2029',
#          'volume_1day': '37129.2029',
#          'volume_7day': '689573.16776665'},
#  'PST': {'24H_fluctate': '-5',
#          '24H_fluctate_rate': '-4.38',
#          'average_price': '111.5105',
#          'buy_price': '109',
#          'closing_price': '109',
#          'max_price': '117',
#          'min_price': '107',
#          'opening_price': '114',
#          'sell_price': '110',
#          'units_traded': '809377.14936885',
#          'volume_1day': '809377.14936885',
#          'volume_7day': '9442422.569011780616582618'},
#  'QTUM': {'24H_fluctate': '-85',
#           '24H_fluctate_rate': '-3.31',
#           'average_price': '2494.6324',
#           'buy_price': '2478',
#           'closing_price': '2480',
#           'max_price': '2567',
#           'min_price': '2449',
#           'opening_price': '2565',
#           'sell_price': '2480',
#           'units_traded': '748840.86994719',
#           'volume_1day': '748840.86994719',
#           'volume_7day': '3118040.13225229'},
#  'RDN': {'24H_fluctate': '-43',
#          '24H_fluctate_rate': '-12.83',
#          'average_price': '311.5113',
#          'buy_price': '292',
#          'closing_price': '292',
#          'max_price': '345',
#          'min_price': '279',
#          'opening_price': '335',
#          'sell_price': '296',
#          'units_traded': '7275075.18579332',
#          'volume_1day': '7275075.18579332',
#          'volume_7day': '25578707.068705808601343468'},
#  'REP': {'24H_fluctate': '-2800',
#          '24H_fluctate_rate': '-2.85',
#          'average_price': '96872.8763',
#          'buy_price': '95400',
#          'closing_price': '95400',
#          'max_price': '99300',
#          'min_price': '94800',
#          'opening_price': '98200',
#          'sell_price': '96050',
#          'units_traded': '3599.78825605',
#          'volume_1day': '3599.78825605',
#          'volume_7day': '94089.046981661535728315'},
#  'RNT': {'24H_fluctate': '-10',
#          '24H_fluctate_rate': '-6.84',
#          'average_price': '145.5534',
#          'buy_price': '136',
#          'closing_price': '136',
#          'max_price': '183',
#          'min_price': '116',
#          'opening_price': '146',
#          'sell_price': '137',
#          'units_traded': '83151073.76027222',
#          'volume_1day': '83151073.76027222',
#          'volume_7day': '187463163.476117765839833516'},
#  'ROM': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '0.1264',
#          'buy_price': '0.12',
#          'closing_price': '0.13',
#          'max_price': '0.13',
#          'min_price': '0.12',
#          'opening_price': '0.13',
#          'sell_price': '0.13',
#          'units_traded': '42622051567.13233077',
#          'volume_1day': '42622051567.13233077',
#          'volume_7day': '217179573717.972943198764699686'},
#  'SALT': {'24H_fluctate': '-14',
#           '24H_fluctate_rate': '-5.01',
#           'average_price': '273.5713',
#           'buy_price': '264',
#           'closing_price': '265',
#           'max_price': '289',
#           'min_price': '262',
#           'opening_price': '279',
#           'sell_price': '266',
#           'units_traded': '1438359.00161115',
#           'volume_1day': '1438359.00161115',
#           'volume_7day': '12810612.05632145'},
#  'SNT': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '116.4938',
#          'buy_price': '115',
#          'closing_price': '116',
#          'max_price': '120',
#          'min_price': '112',
#          'opening_price': '116',
#          'sell_price': '116',
#          'units_traded': '1673777.04033482',
#          'volume_1day': '1673777.04033482',
#          'volume_7day': '23871912.718375323118855704'},
#  'STEEM': {'24H_fluctate': '2',
#            '24H_fluctate_rate': '0.10',
#            'average_price': '1825.1971',
#            'buy_price': '1806',
#            'closing_price': '1838',
#            'max_price': '1875',
#            'min_price': '1784',
#            'opening_price': '1836',
#            'sell_price': '1838',
#            'units_traded': '74832.7044933',
#            'volume_1day': '74832.7044933',
#            'volume_7day': '1361876.2548473'},
#  'STRAT': {'24H_fluctate': '-55',
#            '24H_fluctate_rate': '-1.92',
#            'average_price': '2842.2086',
#            'buy_price': '2800',
#            'closing_price': '2800',
#            'max_price': '2919',
#            'min_price': '2751',
#            'opening_price': '2855',
#            'sell_price': '2871',
#            'units_traded': '25154.68209972',
#            'volume_1day': '25154.68209972',
#            'volume_7day': '486163.8338285'},
#  'THETA': {'24H_fluctate': '-1.4',
#            '24H_fluctate_rate': '-2.43',
#            'average_price': '57.9807',
#            'buy_price': '56',
#            'closing_price': '56.1',
#            'max_price': '62.8',
#            'min_price': '55.4',
#            'opening_price': '57.5',
#            'sell_price': '56.1',
#            'units_traded': '18402942.4121032',
#            'volume_1day': '18402942.4121032',
#            'volume_7day': '91438683.160388079266342968'},
#  'TMTG': {'24H_fluctate': '-0.3',
#           '24H_fluctate_rate': '-3.58',
#           'average_price': '8.2441',
#           'buy_price': '8.05',
#           'closing_price': '8.06',
#           'max_price': '8.41',
#           'min_price': '8.03',
#           'opening_price': '8.36',
#           'sell_price': '8.08',
#           'units_traded': '206875150.68385707',
#           'volume_1day': '206875150.68385707',
#           'volume_7day': '1488986071.746575034973863815'},
#  'TRUE': {'24H_fluctate': '22',
#           '24H_fluctate_rate': '7.56',
#           'average_price': '307.0879',
#           'buy_price': '313',
#           'closing_price': '313',
#           'max_price': '337',
#           'min_price': '287',
#           'opening_price': '291',
#           'sell_price': '314',
#           'units_traded': '2409945.23043346',
#           'volume_1day': '2409945.23043346',
#           'volume_7day': '8791779.888040234515508228'},
#  'TRX': {'24H_fluctate': '0.1',
#          '24H_fluctate_rate': '0.45',
#          'average_price': '22.4348',
#          'buy_price': '22.3',
#          'closing_price': '22.3',
#          'max_price': '23.2',
#          'min_price': '21.8',
#          'opening_price': '22.2',
#          'sell_price': '22.4',
#          'units_traded': '222674410.67080231',
#          'volume_1day': '222674410.67080231',
#          'volume_7day': '935786548.73445431'},
#  'VET': {'24H_fluctate': '-0.22',
#          '24H_fluctate_rate': '-3.02',
#          'average_price': '7.193',
#          'buy_price': '7.07',
#          'closing_price': '7.06',
#          'max_price': '7.35',
#          'min_price': '7.06',
#          'opening_price': '7.28',
#          'sell_price': '7.13',
#          'units_traded': '8069066.75728701',
#          'volume_1day': '8069066.75728701',
#          'volume_7day': '72389413.13606151956123794'},
#  'WAVES': {'24H_fluctate': '-16',
#            '24H_fluctate_rate': '-0.46',
#            'average_price': '3484.2532',
#            'buy_price': '3441',
#            'closing_price': '3459',
#            'max_price': '3550',
#            'min_price': '3419',
#            'opening_price': '3475',
#            'sell_price': '3477',
#            'units_traded': '171963.50281167',
#            'volume_1day': '171963.50281167',
#            'volume_7day': '2676223.77340588'},
#  'WAX': {'24H_fluctate': '-2',
#          '24H_fluctate_rate': '-1.86',
#          'average_price': '105.612',
#          'buy_price': '105',
#          'closing_price': '105',
#          'max_price': '108',
#          'min_price': '104',
#          'opening_price': '107',
#          'sell_price': '106',
#          'units_traded': '862237.60649347',
#          'volume_1day': '862237.60649347',
#          'volume_7day': '17447537.18080034'},
#  'WET': {'24H_fluctate': '-0.1',
#          '24H_fluctate_rate': '-0.71',
#          'average_price': '14.0787',
#          'buy_price': '13.9',
#          'closing_price': '13.9',
#          'max_price': '14.4',
#          'min_price': '13.9',
#          'opening_price': '14',
#          'sell_price': '14',
#          'units_traded': '18451960.44528711',
#          'volume_1day': '18451960.44528711',
#          'volume_7day': '194321729.739309116950969508'},
#  'WTC': {'24H_fluctate': '7',
#          '24H_fluctate_rate': '0.55',
#          'average_price': '1285.8985',
#          'buy_price': '1270',
#          'closing_price': '1275',
#          'max_price': '1328',
#          'min_price': '1253',
#          'opening_price': '1268',
#          'sell_price': '1278',
#          'units_traded': '227222.89667532',
#          'volume_1day': '227222.89667532',
#          'volume_7day': '2366696.396717056649794688'},
#  'XEM': {'24H_fluctate': '-0.7',
#          '24H_fluctate_rate': '-0.95',
#          'average_price': '73.227',
#          'buy_price': '72.5',
#          'closing_price': '72.5',
#          'max_price': '75.4',
#          'min_price': '72',
#          'opening_price': '73.2',
#          'sell_price': '73.6',
#          'units_traded': '2054697.57355356',
#          'volume_1day': '2054697.57355356',
#          'volume_7day': '21611286.25553651'},
#  'XLM': {'24H_fluctate': '-4',
#          '24H_fluctate_rate': '-3.07',
#          'average_price': '128.1218',
#          'buy_price': '126',
#          'closing_price': '126',
#          'max_price': '131',
#          'min_price': '126',
#          'opening_price': '130',
#          'sell_price': '127',
#          'units_traded': '4711240.43037295',
#          'volume_1day': '4711240.43037295',
#          'volume_7day': '47693983.82684493'},
#  'XMR': {'24H_fluctate': '-1650',
#          '24H_fluctate_rate': '-2.88',
#          'average_price': '55903.4663',
#          'buy_price': '55450',
#          'closing_price': '55450',
#          'max_price': '57500',
#          'min_price': '55000',
#          'opening_price': '57100',
#          'sell_price': '55600',
#          'units_traded': '13719296.83939034',
#          'volume_1day': '13719296.83939034',
#          'volume_7day': '69032363.786124596036'},
#  'XRP': {'24H_fluctate': '-10',
#          '24H_fluctate_rate': '-2.43',
#          'average_price': '403.9877',
#          'buy_price': '400',
#          'closing_price': '400',
#          'max_price': '413',
#          'min_price': '397',
#          'opening_price': '410',
#          'sell_price': '401',
#          'units_traded': '46184133.22364995',
#          'volume_1day': '46184133.22364995',
#          'volume_7day': '473457433.37100645'},
#  'XVG': {'24H_fluctate': '-0.05',
#          '24H_fluctate_rate': '-0.63',
#          'average_price': '7.8667',
#          'buy_price': '7.75',
#          'closing_price': '7.86',
#          'max_price': '8.04',
#          'min_price': '7.72',
#          'opening_price': '7.91',
#          'sell_price': '7.85',
#          'units_traded': '5760535.02915987',
#          'volume_1day': '5760535.02915987',
#          'volume_7day': '51376530.06264364'},
#  'ZEC': {'24H_fluctate': '-2100',
#          '24H_fluctate_rate': '-3.12',
#          'average_price': '65695.5555',
#          'buy_price': '64800',
#          'closing_price': '65000',
#          'max_price': '67350',
#          'min_price': '64150',
#          'opening_price': '67100',
#          'sell_price': '65000',
#          'units_traded': '36077.76024304',
#          'volume_1day': '36077.76024304',
#          'volume_7day': '33443375.24532229'},
#  'ZIL': {'24H_fluctate': '-0.3',
#          '24H_fluctate_rate': '-1.33',
#          'average_price': '22.3674',
#          'buy_price': '22.1',
#          'closing_price': '22.2',
#          'max_price': '22.7',
#          'min_price': '22',
#          'opening_price': '22.5',
#          'sell_price': '22.2',
#          'units_traded': '19210070.71019869',
#          'volume_1day': '19210070.71019869',
#          'volume_7day': '457099604.118413354635'},
#  'ZRX': {'24H_fluctate': '1',
#          '24H_fluctate_rate': '0.27',
#          'average_price': '363.79',
#          'buy_price': '360',
#          'closing_price': '362',
#          'max_price': '370',
#          'min_price': '356',
#          'opening_price': '361',
#          'sell_price': '361',
#          'units_traded': '1008766.76755099',
#          'volume_1day': '1008766.76755099',
#          'volume_7day': '5921899.187381677377380573'},
#  'date': '1546569057323'}

# %%
#강사님 풀이**************value값이 딕셔너리인 애들만 처리한다**********************

for key, value in currency.items():
    if type(value) == type(dict()):
        bdp = float(value['max_price']) - float(value['min_price'])
        if float(value['opening_price']) + bdp > float(value['max_price']):
            print(f"{key:5} 상승장")    #:5를 쓰면 일정하게 띄어쓰기 되어 나온다. 
        else:
            print(f"{key:5} 하락장")
# Out:
# BTC   상승장
# ETH   상승장
# DASH  상승장
# LTC   상승장
# ETC   상승장
# XRP   상승장
# BCH   상승장
# XMR   상승장
# ZEC   상승장
# QTUM  상승장
# BTG   상승장
# EOS   상승장
# ICX   상승장
# VET   상승장
# TRX   상승장
# ELF   상승장
# MITH  상승장
# MCO   상승장
# OMG   상승장
# KNC   상승장
# GNT   상승장
# ZIL   상승장
# ETHOS 상승장
# PAY   상승장
# WAX   상승장
# POWR  상승장
# LRC   상승장
# GTO   상승장
# STEEM 상승장
# STRAT 상승장
# ZRX   상승장
# REP   상승장
# AE    상승장
# XEM   상승장
# SNT   상승장
# ADA   상승장
# PPT   상승장
# CTXC  상승장
# CMT   상승장
# THETA 상승장
# WTC   상승장
# ITC   상승장
# TRUE  상승장
# ABT   상승장
# RNT   상승장
# PLY   상승장
# WAVES 상승장
# LINK  상승장
# ENJ   상승장
# PST   상승장
# SALT  상승장
# RDN   상승장
# LOOM  상승장
# BHPC  상승장
# PIVX  상승장
# INS   상승장
# BCD   상승장
# BZNT  상승장
# XLM   상승장
# OCN   상승장
# BSV   상승장
# TMTG  상승장
# BAT   상승장
# WET   상승장
# XVG   상승장
# IOST  상승장
# POLY  상승장
# HC    상승장
# ROM   상승장
# AMO   상승장

# %%
# 아래에 코드를 작성하세요.
for key in currency.keys():
    
    max = float(currency[key]['max_price'])
#     print(max)
    min = float(currency[key]['min_price'])
    open = float(currency[key]['opening_price'])

    change = max - min
    print(key, end=' ')
    if open + change > max:
        print("상승장")
    else:
        print("하락장")
# Out:
# BTC 상승장
# ETH 상승장
# DASH 상승장
# LTC 상승장
# ETC 상승장
# XRP 상승장
# BCH 상승장
# XMR 상승장
# ZEC 상승장
# QTUM 상승장
# BTG 상승장
# EOS 상승장
# ICX 상승장
# VET 상승장
# TRX 상승장
# ELF 상승장
# MITH 상승장
# MCO 상승장
# OMG 상승장
# KNC 상승장
# GNT 상승장
# ZIL 상승장
# ETHOS 상승장
# PAY 상승장
# WAX 상승장
# POWR 상승장
# LRC 상승장
# GTO 상승장
# STEEM 상승장
# STRAT 상승장
# ZRX 상승장
# REP 상승장
# AE 상승장
# XEM 상승장
# SNT 상승장
# ADA 상승장
# PPT 상승장
# CTXC 상승장
# CMT 상승장
# THETA 상승장
# WTC 상승장
# ITC 상승장
# TRUE 상승장
# ABT 상승장
# RNT 상승장
# PLY 상승장
# WAVES 상승장
# LINK 상승장
# ENJ 상승장
# PST 상승장
# SALT 상승장
# RDN 상승장
# LOOM 상승장
# BHPC 상승장
# PIVX 상승장
# INS 상승장
# BCD 상승장
# BZNT 상승장
# XLM 상승장
# OCN 상승장
# BSV 상승장
# TMTG 상승장
# BAT 상승장
# WET 상승장
# XVG 상승장
# IOST 상승장
# POLY 상승장
# HC 상승장
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-b11e6b5f6b34> in <module>
#       2 for key in currency.keys():
#       3
# ----> 4     max = float(currency[key]['max_price'])
#       5 #     print(max)
#       6     min = float(currency[key]['min_price'])
#
# TypeError: list indices must be integers or slices, not str
